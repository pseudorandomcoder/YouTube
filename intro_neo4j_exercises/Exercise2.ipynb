# %%
# :play intro-neo4j-exercises
# Exercise 2

# %%
# Imports
from neo4j import GraphDatabase
import pandas as pd

# %%
# Connection to Graph Database
user = 'neo4j'
pw = 'abc123'
uri = 'bolt://localhost:7687'
neo4j_driver = GraphDatabase.driver(uri, auth=(user, pw), encrypted = False)

# %%
# # Same Database as Exercise 1
# with open('./Exercise1Database.cypher', 'r') as f_read: 
#   create_db_cypher = f_read.read()

# with neo4j_driver.session() as session:
#     for cypher in create_db_cypher.split(';'): # statements are split by ';'
#         session.run(cypher)

# %% [markdown]
# Exercise 2.1: Retrieve all movies that were released in a specific year (Instructions)
#
# Retrieve all Movie nodes that have a released property value of 2003.

# %%
cypher = 'MATCH (m:Movie {released: 2003}) RETURN m'
with neo4j_driver.session() as session:
    result = session.run(cypher)
    for r in result.value():
        print(r)
# Out:
# <Node id=9 labels={'Movie'} properties={'title': 'The Matrix Reloaded', 'tagline': 'Free your mind', 'released': 2003}>
# <Node id=10 labels={'Movie'} properties={'title': 'The Matrix Revolutions', 'tagline': 'Everything that has a beginning has an end', 'released': 2003}>
# <Node id=154 labels={'Movie'} properties={'title': "Something's Gotta Give", 'released': 2003}>

# %% [markdown]
# Exercise 2.2: View the retrieved results as a table (Instructions)
# View the results you just viewed in Neo4j Browser as a table.

# %%
# in neo4j browser, you just click the table icon after running the cypher. Here, let's make a df
movies2003 = pd.DataFrame(columns=['id', 'title', 'tagline', 'released'])
cypher = 'MATCH (m:Movie {released: 2003}) RETURN m'
with neo4j_driver.session() as session:
    result = session.run(cypher)
    for r in result.value():
        new_row = {'id':r.id, 'title': r['title'], 'tagline': r['tagline'], 'released': r['released']}
        movies2003 = movies2003.append(new_row, ignore_index=True)
    movies2003 = movies2003.set_index('id')
movies2003
# Out:
#                       title                                     tagline  \
# id
# 9       The Matrix Reloaded                              Free your mind
# 10   The Matrix Revolutions  Everything that has a beginning has an end
# 154  Something's Gotta Give                                        None
#
#     released
# id
# 9       2003
# 10      2003
# 154     2003

# %% [markdown]
# Exercise 2.2: View the retrieved results as a table (Taking it further- optional)
#
# Retrieve all movie nodes in the database and view the data as a table. Notice the values for the released property for each node.
#
# Try querying the graph using different years.

# %%
movies_all = pd.DataFrame(columns=['id', 'title', 'tagline', 'released'])
cypher = 'MATCH (m:Movie) RETURN m'
with neo4j_driver.session() as session:
    result = session.run(cypher)
    for r in result.value():
        new_row = {'id':r.id, 'title': r['title'], 'tagline': r['tagline'], 'released': r['released']}
        movies_all = movies_all.append(new_row, ignore_index=True)
    movies_all = movies_all.set_index('id')
movies_all
# Out:
#                                title  \
# id
# 0                         The Matrix
# 9                The Matrix Reloaded
# 10            The Matrix Revolutions
# 11              The Devil's Advocate
# 15                    A Few Good Men
# 29                           Top Gun
# 37                     Jerry Maguire
# 46                       Stand By Me
# 52                As Good as It Gets
# 56              What Dreams May Come
# 62            Snow Falling on Cedars
# 67                   You've Got Mail
# 73              Sleepless in Seattle
# 78            Joe Versus the Volcano
# 81              When Harry Met Sally
# 85                 That Thing You Do
# 87                  The Replacements
# 92                        RescueDawn
# 95                      The Birdcage
# 97                        Unforgiven
# 100                  Johnny Mnemonic
# 105                      Cloud Atlas
# 111                The Da Vinci Code
# 116                   V for Vendetta
# 121                      Speed Racer
# 128                   Ninja Assassin
# 130                   The Green Mile
# 137                      Frost/Nixon
# 141                            Hoffa
# 144                        Apollo 13
# 147                          Twister
# 150                        Cast Away
# 152  One Flew Over the Cuckoo's Nest
# 154           Something's Gotta Give
# 157                 Bicentennial Man
# 159             Charlie Wilson's War
# 161                The Polar Express
# 162            A League of Their Own
#
#                                                tagline released
# id
# 0                            Welcome to the Real World     1999
# 9                                       Free your mind     2003
# 10          Everything that has a beginning has an end     2003
# 11                           Evil has its winning ways     1997
# 15   In the heart of the nation's capital, in a cou...     1992
# 29                I feel the need, the need for speed.     1986
# 37                    The rest of his life begins now.     2000
# 46   For some, it's the last real taste of innocenc...     1986
# 52   A comedy from the heart that goes for the throat.     1997
# 56   After life there is more. The end is just the ...     1998
# 62                          First loves last. Forever.     1999
# 67                 At odds in life... in love on-line.     1998
# 73   What if someone you never met, someone you nev...     1993
# 78           A story of love, lava and burning desire.     1990
# 81                 At odds in life... in love on-line.     1998
# 85   In every life there comes a time when that thi...     1996
# 87   Pain heals, Chicks dig scars... Glory lasts fo...     2000
# 92   Based on the extraordinary true story of one m...     2006
# 95                                     Come as you are     1996
# 97               It's a hell of a thing, killing a man     1992
# 100  The hottest data on earth. In the coolest head...     1995
# 105                            Everything is connected     2012
# 111                                    Break The Codes     2006
# 116                                  Freedom! Forever!     2006
# 121                                Speed has no limits     2008
# 128       Prepare to enter a secret world of assassins     2009
# 130                   Walk a mile you'll never forget.     1999
# 137     400 million people were waiting for the truth.     2008
# 141             He didn't want law. He wanted justice.     1992
# 144                        Houston, we have a problem.     1995
# 147                    Don't Breathe. Don't Look Back.     1996
# 150      At the edge of the world, his journey begins.     2000
# 152            If he's crazy, what does that make you?     1975
# 154                                               None     2003
# 157  One robot's 200 year journey to become an ordi...     1999
# 159  A stiff drink. A little mascara. A lot of nerv...     2007
# 161                     This Holiday Seasonâ€¦ Believe     2004
# 162  Once in a lifetime you get a chance to do some...     1992

# %% [markdown]
# Exercise 2.3: Query the database for all property keys (Instructions)
#
# You want to know the existing property keys used in a graph. This will help you to write Cypher queries that utilizes property keys for filtering data or for returning data.
#
# Query the database for all property keys.

# %%
cypher = 'CALL db.propertyKeys()'
propertyKeys = []
with neo4j_driver.session() as session:
    result = session.run(cypher)
    for r in result:
        propertyKeys.append(r['propertyKey'])
propertyKeys
# Out:
# ['tagline', 'title', 'released', 'born', 'name', 'roles', 'summary', 'rating']

# %% [markdown]
# Exercise 2.4: Retrieve all Movies released in a specific year, returning their titles (Instructions)
#
# Rather than returning the nodes that satisfy a query, you want to return data from the nodes.
#
# Retrieve all Movies released in 2006, returning their titles.

# %%
# Use a function to wrap the call:
def get_title_for_year(year):
    cypher = 'MATCH (m:Movie {released: $year}) RETURN m.title'
    titles = []
    with neo4j_driver.session() as session:
        result = session.run(cypher, year=year)
        for r in result:
            titles.append(r['m.title'])
    return titles

# %%
get_title_for_year(2006)
# Out:
# ['RescueDawn', 'The Da Vinci Code', 'V for Vendetta']

# %% [markdown]
# Exercise 2.4: Retrieve all Movies released in a specific year, returning their titles (Taking it further - optional)
#
# Retrieve all Movie nodes and view them as a table. Observe the properties that Movie nodes have.
#
# Query the database using a different year and also return more property values.

# %%
# Use a function to wrap the call:
def get_movies_for_year(year):
    cypher = 'MATCH (m:Movie {released: $year}) RETURN m'
    movies = []
    with neo4j_driver.session() as session:
        result = session.run(cypher, year=year)
        for r in result:
            movies.append(r['m'])
    return movies

# %%
m_list = get_movies_for_year(2006)
for m in m_list:
    print(f"Node ID# {m.id} {m['title']}") # can display any other properties like this
# Out:
# Node ID# 92 RescueDawn
# Node ID# 111 The Da Vinci Code
# Node ID# 116 V for Vendetta

# %%
Exercise 2.5: Display title, released, and tagline values for every Movie node in the graph (Instructions)

When you start working with a graph, it is sometimes helpful to simply view property values. This can sometimes help to inform you about future queries you may want to execute against the graph.

Retrieve all Movie nodes from the database and return the title, released, and tagline values.

# %%
cypher = 'MATCH (m:Movie) RETURN m.title, m.released, m.tagline'
with neo4j_driver.session() as session:
    result = session.run(cypher)
    for r in result: # notice not taking value here :O
        print(dict(r)) # can access individual items w/ r['m.title'], or convert record to dict
# Out:
# {'m.title': 'The Matrix', 'm.released': 1999, 'm.tagline': 'Welcome to the Real World'}
# {'m.title': 'The Matrix Reloaded', 'm.released': 2003, 'm.tagline': 'Free your mind'}
# {'m.title': 'The Matrix Revolutions', 'm.released': 2003, 'm.tagline': 'Everything that has a beginning has an end'}
# {'m.title': "The Devil's Advocate", 'm.released': 1997, 'm.tagline': 'Evil has its winning ways'}
# {'m.title': 'A Few Good Men', 'm.released': 1992, 'm.tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth."}
# {'m.title': 'Top Gun', 'm.released': 1986, 'm.tagline': 'I feel the need, the need for speed.'}
# {'m.title': 'Jerry Maguire', 'm.released': 2000, 'm.tagline': 'The rest of his life begins now.'}
# {'m.title': 'Stand By Me', 'm.released': 1986, 'm.tagline': "For some, it's the last real taste of innocence, and the first real taste of life. But for everyone, it's the time that memories are made of."}
# {'m.title': 'As Good as It Gets', 'm.released': 1997, 'm.tagline': 'A comedy from the heart that goes for the throat.'}
# {'m.title': 'What Dreams May Come', 'm.released': 1998, 'm.tagline': 'After life there is more. The end is just the beginning.'}
# {'m.title': 'Snow Falling on Cedars', 'm.released': 1999, 'm.tagline': 'First loves last. Forever.'}
# {'m.title': "You've Got Mail", 'm.released': 1998, 'm.tagline': 'At odds in life... in love on-line.'}
# {'m.title': 'Sleepless in Seattle', 'm.released': 1993, 'm.tagline': 'What if someone you never met, someone you never saw, someone you never knew was the only someone for you?'}
# {'m.title': 'Joe Versus the Volcano', 'm.released': 1990, 'm.tagline': 'A story of love, lava and burning desire.'}
# {'m.title': 'When Harry Met Sally', 'm.released': 1998, 'm.tagline': 'At odds in life... in love on-line.'}
# {'m.title': 'That Thing You Do', 'm.released': 1996, 'm.tagline': 'In every life there comes a time when that thing you dream becomes that thing you do'}
# {'m.title': 'The Replacements', 'm.released': 2000, 'm.tagline': 'Pain heals, Chicks dig scars... Glory lasts forever'}
# {'m.title': 'RescueDawn', 'm.released': 2006, 'm.tagline': "Based on the extraordinary true story of one man's fight for freedom"}
# {'m.title': 'The Birdcage', 'm.released': 1996, 'm.tagline': 'Come as you are'}
# {'m.title': 'Unforgiven', 'm.released': 1992, 'm.tagline': "It's a hell of a thing, killing a man"}
# {'m.title': 'Johnny Mnemonic', 'm.released': 1995, 'm.tagline': 'The hottest data on earth. In the coolest head in town'}
# {'m.title': 'Cloud Atlas', 'm.released': 2012, 'm.tagline': 'Everything is connected'}
# {'m.title': 'The Da Vinci Code', 'm.released': 2006, 'm.tagline': 'Break The Codes'}
# {'m.title': 'V for Vendetta', 'm.released': 2006, 'm.tagline': 'Freedom! Forever!'}
# {'m.title': 'Speed Racer', 'm.released': 2008, 'm.tagline': 'Speed has no limits'}
# {'m.title': 'Ninja Assassin', 'm.released': 2009, 'm.tagline': 'Prepare to enter a secret world of assassins'}
# {'m.title': 'The Green Mile', 'm.released': 1999, 'm.tagline': "Walk a mile you'll never forget."}
# {'m.title': 'Frost/Nixon', 'm.released': 2008, 'm.tagline': '400 million people were waiting for the truth.'}
# {'m.title': 'Hoffa', 'm.released': 1992, 'm.tagline': "He didn't want law. He wanted justice."}
# {'m.title': 'Apollo 13', 'm.released': 1995, 'm.tagline': 'Houston, we have a problem.'}
# {'m.title': 'Twister', 'm.released': 1996, 'm.tagline': "Don't Breathe. Don't Look Back."}
# {'m.title': 'Cast Away', 'm.released': 2000, 'm.tagline': 'At the edge of the world, his journey begins.'}
# {'m.title': "One Flew Over the Cuckoo's Nest", 'm.released': 1975, 'm.tagline': "If he's crazy, what does that make you?"}
# {'m.title': "Something's Gotta Give", 'm.released': 2003, 'm.tagline': None}
# {'m.title': 'Bicentennial Man', 'm.released': 1999, 'm.tagline': "One robot's 200 year journey to become an ordinary man."}
# {'m.title': "Charlie Wilson's War", 'm.released': 2007, 'm.tagline': "A stiff drink. A little mascara. A lot of nerve. Who said they couldn't bring down the Soviet empire."}
# {'m.title': 'The Polar Express', 'm.released': 2004, 'm.tagline': 'This Holiday Seasonâ€¦ Believe'}
# {'m.title': 'A League of Their Own', 'm.released': 1992, 'm.tagline': 'Once in a lifetime you get a chance to do something different.'}

# %% [markdown]
# Exercise 2.6: Display more user-friendly headers in the table (Instructions)
#
# Modify the query you just ran so that the headings for the columns of the table returned are more descriptive.

# %%
# Changing the previous code so the dictionary key are more friendly:
cypher = 'MATCH (m:Movie) RETURN m.title AS `movie title`, m.released AS release, m.tagline AS tagline'
with neo4j_driver.session() as session:
    result = session.run(cypher)
    for r in result: # notice not taking value here :O
        print(dict(r)) # can access individual items w/ r['m.title'], or convert record to dict
# Out:
# {'movie title': 'The Matrix', 'release': 1999, 'tagline': 'Welcome to the Real World'}
# {'movie title': 'The Matrix Reloaded', 'release': 2003, 'tagline': 'Free your mind'}
# {'movie title': 'The Matrix Revolutions', 'release': 2003, 'tagline': 'Everything that has a beginning has an end'}
# {'movie title': "The Devil's Advocate", 'release': 1997, 'tagline': 'Evil has its winning ways'}
# {'movie title': 'A Few Good Men', 'release': 1992, 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth."}
# {'movie title': 'Top Gun', 'release': 1986, 'tagline': 'I feel the need, the need for speed.'}
# {'movie title': 'Jerry Maguire', 'release': 2000, 'tagline': 'The rest of his life begins now.'}
# {'movie title': 'Stand By Me', 'release': 1986, 'tagline': "For some, it's the last real taste of innocence, and the first real taste of life. But for everyone, it's the time that memories are made of."}
# {'movie title': 'As Good as It Gets', 'release': 1997, 'tagline': 'A comedy from the heart that goes for the throat.'}
# {'movie title': 'What Dreams May Come', 'release': 1998, 'tagline': 'After life there is more. The end is just the beginning.'}
# {'movie title': 'Snow Falling on Cedars', 'release': 1999, 'tagline': 'First loves last. Forever.'}
# {'movie title': "You've Got Mail", 'release': 1998, 'tagline': 'At odds in life... in love on-line.'}
# {'movie title': 'Sleepless in Seattle', 'release': 1993, 'tagline': 'What if someone you never met, someone you never saw, someone you never knew was the only someone for you?'}
# {'movie title': 'Joe Versus the Volcano', 'release': 1990, 'tagline': 'A story of love, lava and burning desire.'}
# {'movie title': 'When Harry Met Sally', 'release': 1998, 'tagline': 'At odds in life... in love on-line.'}
# {'movie title': 'That Thing You Do', 'release': 1996, 'tagline': 'In every life there comes a time when that thing you dream becomes that thing you do'}
# {'movie title': 'The Replacements', 'release': 2000, 'tagline': 'Pain heals, Chicks dig scars... Glory lasts forever'}
# {'movie title': 'RescueDawn', 'release': 2006, 'tagline': "Based on the extraordinary true story of one man's fight for freedom"}
# {'movie title': 'The Birdcage', 'release': 1996, 'tagline': 'Come as you are'}
# {'movie title': 'Unforgiven', 'release': 1992, 'tagline': "It's a hell of a thing, killing a man"}
# {'movie title': 'Johnny Mnemonic', 'release': 1995, 'tagline': 'The hottest data on earth. In the coolest head in town'}
# {'movie title': 'Cloud Atlas', 'release': 2012, 'tagline': 'Everything is connected'}
# {'movie title': 'The Da Vinci Code', 'release': 2006, 'tagline': 'Break The Codes'}
# {'movie title': 'V for Vendetta', 'release': 2006, 'tagline': 'Freedom! Forever!'}
# {'movie title': 'Speed Racer', 'release': 2008, 'tagline': 'Speed has no limits'}
# {'movie title': 'Ninja Assassin', 'release': 2009, 'tagline': 'Prepare to enter a secret world of assassins'}
# {'movie title': 'The Green Mile', 'release': 1999, 'tagline': "Walk a mile you'll never forget."}
# {'movie title': 'Frost/Nixon', 'release': 2008, 'tagline': '400 million people were waiting for the truth.'}
# {'movie title': 'Hoffa', 'release': 1992, 'tagline': "He didn't want law. He wanted justice."}
# {'movie title': 'Apollo 13', 'release': 1995, 'tagline': 'Houston, we have a problem.'}
# {'movie title': 'Twister', 'release': 1996, 'tagline': "Don't Breathe. Don't Look Back."}
# {'movie title': 'Cast Away', 'release': 2000, 'tagline': 'At the edge of the world, his journey begins.'}
# {'movie title': "One Flew Over the Cuckoo's Nest", 'release': 1975, 'tagline': "If he's crazy, what does that make you?"}
# {'movie title': "Something's Gotta Give", 'release': 2003, 'tagline': None}
# {'movie title': 'Bicentennial Man', 'release': 1999, 'tagline': "One robot's 200 year journey to become an ordinary man."}
# {'movie title': "Charlie Wilson's War", 'release': 2007, 'tagline': "A stiff drink. A little mascara. A lot of nerve. Who said they couldn't bring down the Soviet empire."}
# {'movie title': 'The Polar Express', 'release': 2004, 'tagline': 'This Holiday Seasonâ€¦ Believe'}
# {'movie title': 'A League of Their Own', 'release': 1992, 'tagline': 'Once in a lifetime you get a chance to do something different.'}
